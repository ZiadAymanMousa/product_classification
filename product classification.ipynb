# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import array_to_img, img_to_array, load_img
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
import pandas as pd
import numpy as np
import os
from PIL import Image
import shutil
from sklearn.metrics import accuracy_score

# %%
def convert_to_jpeg(file_path):
    try:
        img = Image.open(file_path)
        rgb_img = img.convert('RGB')
        rgb_img.save(file_path, format='JPEG', quality=90)
    except Exception as e:
        print(f"Error converting file {file_path} to JPEG: {e}")

# %%
main_dir = '/kaggle/input/products/train/train'
writable_dir = '/kaggle/working/train'


shutil.copytree(main_dir, writable_dir)


for subdir, dirs, files in os.walk(writable_dir):
    for file in files:
        file_path = os.path.join(subdir, file)
        convert_to_jpeg(file_path)

# %%
main_dir = '/kaggle/input/products/validation/validation'
writable_dir = '/kaggle/working/validation'


shutil.copytree(main_dir, writable_dir)


for subdir, dirs, files in os.walk(writable_dir):
    for file in files:
        file_path = os.path.join(subdir, file)
        convert_to_jpeg(file_path)

# %%
train_dir = '/kaggle/working/train'
val_dir = '/kaggle/working/validation'

# %%
datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest',
    brightness_range=[0.1, 0.9]
)

# %%
kernel_size = (3,3)
pool_size = (2,2)
first_filters = 32
second_filters = 64
third_filtesr = 128

# %%
dropout_conv = 0.3
dropout_dense = 0.3

# %%
IMAGE_SIZE = 240

CLASSES = 4

# %%
#Model setup
model = Sequential()
model.add(Conv2D(first_filters,kernel_size,activation='relu',input_shape = (IMAGE_SIZE,IMAGE_SIZE,3))) #This 3, would be a 1 if the images are gray
model.add(Conv2D(first_filters,kernel_size,activation='relu'))
model.add(Conv2D(first_filters,kernel_size,activation='relu'))
model.add(MaxPool2D(pool_size=pool_size))
model.add(Dropout(dropout_conv))

model.add(Conv2D(second_filters,kernel_size,activation='relu'))
model.add(Conv2D(second_filters,kernel_size,activation='relu'))
model.add(Conv2D(second_filters,kernel_size,activation='relu'))
model.add(MaxPool2D(pool_size=pool_size))
model.add(Dropout(dropout_conv))

model.add(Conv2D(third_filtesr,kernel_size,activation='relu'))
model.add(Conv2D(third_filtesr,kernel_size,activation='relu'))
model.add(Conv2D(third_filtesr,kernel_size,activation='relu'))
model.add(MaxPool2D(pool_size=pool_size))
model.add(Dropout(dropout_conv))

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dropout(dropout_dense))
model.add(Dense(4, activation='softmax'))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
model.compile(Adam(learning_rate=0.0001), loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 238, 238, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 236, 236, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 234, 234, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 117, 117, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 117, 117, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 115, 115, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 113, 113, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 111, 111, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 55, 55, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 55, 55, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 53, 53, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 51, 51, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 49, 49, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 73728)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    18,874,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,356,420 (73.84 MB)
#  Trainable params: 19,356,420 (73.84 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
batch_size = 16

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

# %%
filepath = '/kaggle/working/eshta.keras'

# %%
checkpoint = ModelCheckpoint(filepath,monitor='val_accuracy',verbose=1, save_best_only=True,mode='max')

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy',factor=0.5, patience=3, verbose=1, mode='max',min_lr=0.00001)
callsback = [checkpoint, reduce_lr]

# %%
train_generator = train_datagen.flow_from_directory(
    '/kaggle/working/train', 
    target_size=(IMAGE_SIZE, IMAGE_SIZE), 
    batch_size=batch_size,
    class_mode='categorical'  
)


validation_generator = test_datagen.flow_from_directory(
    '/kaggle/working/validation',
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 428 images belonging to 4 classes.
# Found 90 images belonging to 4 classes.

# %%
class_names = list(train_generator.class_indices.keys())

# %%
model.fit(
    train_generator,
    steps_per_epoch=2000 // batch_size,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=800 // batch_size,
    callbacks=callsback
)
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   1/125 ━━━━━━━━━━━━━━━━━━━━ 1:15:44 37s/step - accuracy: 0.3125 - loss: 1.3807
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710478242.924107     184 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1710478242.945765     184 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#   2/125 ━━━━━━━━━━━━━━━━━━━━ 51:32 25s/step - accuracy: 0.3348 - loss: 1.3775
# W0000 00:00:1710478268.119872     187 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 1:53 1s/step - accuracy: 0.2872 - loss: 1.3905
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# W0000 00:00:1710478273.996325     185 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.43333, saving model to /kaggle/working/eshta.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 75s 313ms/step - accuracy: 0.2782 - loss: 1.3885 - val_accuracy: 0.4333 - val_loss: 1.3759 - learning_rate: 1.0000e-04
# Epoch 2/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 187ms/step - accuracy: 0.3052 - loss: 1.3720
# Epoch 2: val_accuracy improved from 0.43333 to 0.46667, saving model to /kaggle/working/eshta.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.3352 - loss: 1.3632 - val_accuracy: 0.4667 - val_loss: 1.3103 - learning_rate: 1.0000e-04
# Epoch 3/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 187ms/step - accuracy: 0.3371 - loss: 1.3071
# Epoch 3: val_accuracy improved from 0.46667 to 0.61111, saving model to /kaggle/working/eshta.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - accuracy: 0.3842 - loss: 1.2666 - val_accuracy: 0.6111 - val_loss: 1.0403 - learning_rate: 1.0000e-04
# Epoch 4/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 195ms/step - accuracy: 0.5178 - loss: 1.1383
# Epoch 4: val_accuracy did not improve from 0.61111
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.5277 - loss: 1.1249 - val_accuracy: 0.6111 - val_loss: 0.9829 - learning_rate: 1.0000e-04
# Epoch 5/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 200ms/step - accuracy: 0.5913 - loss: 1.0627
# Epoch 5: val_accuracy did not improve from 0.61111
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.5692 - loss: 1.0576 - val_accuracy: 0.5889 - val_loss: 1.0134 - learning_rate: 1.0000e-04
# Epoch 6/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 194ms/step - accuracy: 0.6452 - loss: 0.9148
# Epoch 6: val_accuracy did not improve from 0.61111
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.6394 - loss: 0.9373 - val_accuracy: 0.5444 - val_loss: 1.1094 - learning_rate: 1.0000e-04
# Epoch 7/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 195ms/step - accuracy: 0.6282 - loss: 0.9636
# Epoch 7: val_accuracy improved from 0.61111 to 0.66667, saving model to /kaggle/working/eshta.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.6339 - loss: 0.9422 - val_accuracy: 0.6667 - val_loss: 0.8431 - learning_rate: 5.0000e-05
# Epoch 8/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 198ms/step - accuracy: 0.6572 - loss: 0.8346
# Epoch 8: val_accuracy improved from 0.66667 to 0.76667, saving model to /kaggle/working/eshta.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.6750 - loss: 0.8302 - val_accuracy: 0.7667 - val_loss: 0.7074 - learning_rate: 5.0000e-05
# Epoch 9/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - accuracy: 0.6821 - loss: 0.8085
# Epoch 9: val_accuracy did not improve from 0.76667
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.6785 - loss: 0.8226 - val_accuracy: 0.7111 - val_loss: 0.8709 - learning_rate: 5.0000e-05
# Epoch 10/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 194ms/step - accuracy: 0.6690 - loss: 0.7801
# Epoch 10: val_accuracy did not improve from 0.76667
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.6757 - loss: 0.8034 - val_accuracy: 0.7222 - val_loss: 0.6949 - learning_rate: 5.0000e-05
# Epoch 11/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 193ms/step - accuracy: 0.6821 - loss: 0.8127
# Epoch 11: val_accuracy did not improve from 0.76667
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.6914 - loss: 0.7777 - val_accuracy: 0.7333 - val_loss: 0.7068 - learning_rate: 5.0000e-05
# Epoch 12/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 189ms/step - accuracy: 0.7358 - loss: 0.7140
# Epoch 12: val_accuracy did not improve from 0.76667
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7195 - loss: 0.7304 - val_accuracy: 0.7444 - val_loss: 0.6493 - learning_rate: 2.5000e-05
# Epoch 13/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.6984 - loss: 0.7722
# Epoch 13: val_accuracy did not improve from 0.76667
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - accuracy: 0.7077 - loss: 0.7395 - val_accuracy: 0.7667 - val_loss: 0.6326 - learning_rate: 2.5000e-05
# Epoch 14/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 189ms/step - accuracy: 0.7534 - loss: 0.6639
# Epoch 14: val_accuracy did not improve from 0.76667
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.7416 - loss: 0.6885 - val_accuracy: 0.7667 - val_loss: 0.6331 - learning_rate: 2.5000e-05
# Epoch 15/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 202ms/step - accuracy: 0.7687 - loss: 0.6818
# Epoch 15: val_accuracy did not improve from 0.76667
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - accuracy: 0.7504 - loss: 0.6947 - val_accuracy: 0.7667 - val_loss: 0.6315 - learning_rate: 1.2500e-05
# Epoch 16/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - accuracy: 0.7156 - loss: 0.7244
# Epoch 16: val_accuracy improved from 0.76667 to 0.77778, saving model to /kaggle/working/eshta.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.7352 - loss: 0.6953 - val_accuracy: 0.7778 - val_loss: 0.6273 - learning_rate: 1.2500e-05
# Epoch 17/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 198ms/step - accuracy: 0.7494 - loss: 0.6839
# Epoch 17: val_accuracy did not improve from 0.77778
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.7480 - loss: 0.6705 - val_accuracy: 0.7778 - val_loss: 0.6058 - learning_rate: 1.2500e-05
# Epoch 18/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 193ms/step - accuracy: 0.7285 - loss: 0.7172
# Epoch 18: val_accuracy improved from 0.77778 to 0.78889, saving model to /kaggle/working/eshta.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.7325 - loss: 0.7054 - val_accuracy: 0.7889 - val_loss: 0.6264 - learning_rate: 1.2500e-05
# Epoch 19/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 187ms/step - accuracy: 0.7132 - loss: 0.7423
# Epoch 19: val_accuracy did not improve from 0.78889
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7329 - loss: 0.7005 - val_accuracy: 0.7778 - val_loss: 0.6236 - learning_rate: 1.2500e-05
# Epoch 20/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 193ms/step - accuracy: 0.7388 - loss: 0.6140
# Epoch 20: val_accuracy improved from 0.78889 to 0.82222, saving model to /kaggle/working/eshta.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.7403 - loss: 0.6440 - val_accuracy: 0.8222 - val_loss: 0.6262 - learning_rate: 1.2500e-05
# Epoch 21/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 196ms/step - accuracy: 0.7719 - loss: 0.6364
# Epoch 21: val_accuracy did not improve from 0.82222
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.7492 - loss: 0.6416 - val_accuracy: 0.8111 - val_loss: 0.6029 - learning_rate: 1.2500e-05
# Epoch 22/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 194ms/step - accuracy: 0.7588 - loss: 0.6111
# Epoch 22: val_accuracy did not improve from 0.82222
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.7611 - loss: 0.6262 - val_accuracy: 0.8111 - val_loss: 0.6107 - learning_rate: 1.2500e-05
# Epoch 23/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 184ms/step - accuracy: 0.7626 - loss: 0.6486
# Epoch 23: val_accuracy did not improve from 0.82222
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-05.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.7582 - loss: 0.6469 - val_accuracy: 0.8000 - val_loss: 0.5594 - learning_rate: 1.2500e-05
# Epoch 24/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 194ms/step - accuracy: 0.7595 - loss: 0.7073
# Epoch 24: val_accuracy improved from 0.82222 to 0.83333, saving model to /kaggle/working/eshta.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.7649 - loss: 0.6679 - val_accuracy: 0.8333 - val_loss: 0.6198 - learning_rate: 1.0000e-05
# Epoch 25/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 20s 209ms/step - accuracy: 0.7612 - loss: 0.6091
# Epoch 25: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - accuracy: 0.7488 - loss: 0.6479 - val_accuracy: 0.8222 - val_loss: 0.6081 - learning_rate: 1.0000e-05
# Epoch 26/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 202ms/step - accuracy: 0.7370 - loss: 0.6210
# Epoch 26: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - accuracy: 0.7380 - loss: 0.6354 - val_accuracy: 0.8222 - val_loss: 0.5967 - learning_rate: 1.0000e-05
# Epoch 27/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 199ms/step - accuracy: 0.7671 - loss: 0.6237
# Epoch 27: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.7684 - loss: 0.6127 - val_accuracy: 0.8111 - val_loss: 0.6084 - learning_rate: 1.0000e-05
# Epoch 28/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 196ms/step - accuracy: 0.7456 - loss: 0.6722
# Epoch 28: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.7674 - loss: 0.6282 - val_accuracy: 0.8222 - val_loss: 0.5798 - learning_rate: 1.0000e-05
# Epoch 29/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 20s 207ms/step - accuracy: 0.7760 - loss: 0.6099
# Epoch 29: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - accuracy: 0.7703 - loss: 0.6326 - val_accuracy: 0.8111 - val_loss: 0.5807 - learning_rate: 1.0000e-05
# Epoch 30/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 20s 204ms/step - accuracy: 0.7606 - loss: 0.6288
# Epoch 30: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - accuracy: 0.7688 - loss: 0.6211 - val_accuracy: 0.8222 - val_loss: 0.6030 - learning_rate: 1.0000e-05
# Epoch 31/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 188ms/step - accuracy: 0.7673 - loss: 0.5971
# Epoch 31: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7629 - loss: 0.6206 - val_accuracy: 0.8222 - val_loss: 0.5882 - learning_rate: 1.0000e-05
# Epoch 32/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 189ms/step - accuracy: 0.7707 - loss: 0.5633
# Epoch 32: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7655 - loss: 0.5952 - val_accuracy: 0.8000 - val_loss: 0.5700 - learning_rate: 1.0000e-05
# Epoch 33/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 195ms/step - accuracy: 0.7894 - loss: 0.5878
# Epoch 33: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.7768 - loss: 0.6060 - val_accuracy: 0.7889 - val_loss: 0.6048 - learning_rate: 1.0000e-05
# Epoch 34/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 199ms/step - accuracy: 0.7457 - loss: 0.6499
# Epoch 34: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.7692 - loss: 0.6074 - val_accuracy: 0.8111 - val_loss: 0.5521 - learning_rate: 1.0000e-05
# Epoch 35/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 189ms/step - accuracy: 0.7796 - loss: 0.6154
# Epoch 35: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7656 - loss: 0.6134 - val_accuracy: 0.8111 - val_loss: 0.5449 - learning_rate: 1.0000e-05
# Epoch 36/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 194ms/step - accuracy: 0.7525 - loss: 0.6391
# Epoch 36: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.7579 - loss: 0.6203 - val_accuracy: 0.8000 - val_loss: 0.5566 - learning_rate: 1.0000e-05
# Epoch 37/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 201ms/step - accuracy: 0.7977 - loss: 0.5674
# Epoch 37: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - accuracy: 0.7841 - loss: 0.5877 - val_accuracy: 0.8111 - val_loss: 0.5793 - learning_rate: 1.0000e-05
# Epoch 38/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 199ms/step - accuracy: 0.7648 - loss: 0.5778
# Epoch 38: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.7715 - loss: 0.5896 - val_accuracy: 0.7889 - val_loss: 0.5654 - learning_rate: 1.0000e-05
# Epoch 39/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 189ms/step - accuracy: 0.8096 - loss: 0.4865
# Epoch 39: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7830 - loss: 0.5682 - val_accuracy: 0.8000 - val_loss: 0.5264 - learning_rate: 1.0000e-05
# Epoch 40/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 199ms/step - accuracy: 0.7739 - loss: 0.5667
# Epoch 40: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.7716 - loss: 0.5849 - val_accuracy: 0.7889 - val_loss: 0.5648 - learning_rate: 1.0000e-05
# Epoch 41/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.7864 - loss: 0.5553
# Epoch 41: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - accuracy: 0.7780 - loss: 0.5724 - val_accuracy: 0.8000 - val_loss: 0.5641 - learning_rate: 1.0000e-05
# Epoch 42/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 192ms/step - accuracy: 0.8243 - loss: 0.5477
# Epoch 42: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.8045 - loss: 0.5576 - val_accuracy: 0.8111 - val_loss: 0.5176 - learning_rate: 1.0000e-05
# Epoch 43/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 192ms/step - accuracy: 0.7784 - loss: 0.5621
# Epoch 43: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.7799 - loss: 0.5651 - val_accuracy: 0.8222 - val_loss: 0.5169 - learning_rate: 1.0000e-05
# Epoch 44/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 195ms/step - accuracy: 0.7808 - loss: 0.5794
# Epoch 44: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.7786 - loss: 0.5963 - val_accuracy: 0.8000 - val_loss: 0.5636 - learning_rate: 1.0000e-05
# Epoch 45/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 19s 195ms/step - accuracy: 0.8116 - loss: 0.5456
# Epoch 45: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.7999 - loss: 0.5653 - val_accuracy: 0.7778 - val_loss: 0.5536 - learning_rate: 1.0000e-05
# Epoch 46/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - accuracy: 0.7764 - loss: 0.5836
# Epoch 46: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.7814 - loss: 0.5677 - val_accuracy: 0.8000 - val_loss: 0.5178 - learning_rate: 1.0000e-05
# Epoch 47/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 189ms/step - accuracy: 0.8267 - loss: 0.5144
# Epoch 47: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8160 - loss: 0.5484 - val_accuracy: 0.7889 - val_loss: 0.5786 - learning_rate: 1.0000e-05
# Epoch 48/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 190ms/step - accuracy: 0.8025 - loss: 0.5497
# Epoch 48: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7888 - loss: 0.5764 - val_accuracy: 0.8111 - val_loss: 0.5788 - learning_rate: 1.0000e-05
# Epoch 49/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 17s 181ms/step - accuracy: 0.7876 - loss: 0.5632
# Epoch 49: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.7948 - loss: 0.5483 - val_accuracy: 0.8000 - val_loss: 0.5060 - learning_rate: 1.0000e-05
# Epoch 50/50
#  27/125 ━━━━━━━━━━━━━━━━━━━━ 18s 186ms/step - accuracy: 0.7975 - loss: 0.5647
# Epoch 50: val_accuracy did not improve from 0.83333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.7932 - loss: 0.5505 - val_accuracy: 0.7778 - val_loss: 0.5575 - learning_rate: 1.0000e-05

# %%
test_folder_path = '/kaggle/working/validation'

y_true = []
y_pred = []

for class_folder in os.listdir(test_folder_path):
    class_folder_path = os.path.join(test_folder_path, class_folder)
    
    
    for img_file in os.listdir(class_folder_path):
        img_path = os.path.join(class_folder_path, img_file)
        new_image = load_image(img_path, size=(IMAGE_SIZE, IMAGE_SIZE))
        
        
        pred = model.predict(new_image)
        predicted_class = class_names[pred.argmax()]
        y_true.append(class_folder)
        y_pred.append(predicted_class)


accuracy = accuracy_score(y_true, y_pred)

print(f'Test accuracy: {accuracy * 100:.2f}%')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Test accuracy: 77.78%
